# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_Y= pd.read_csv('Tests4')
df_FK=pd.read_csv('X')

# %%
t=[]
t_before=0
index=0

for i in df_Y['t']:
    t.append(t_before+i)
    t_before=t_before+i
    index=index+1
    if (index==9): break

# %%
Y=[]
index=0
for i in df_Y['x']:
    Y.append(i)
    index=index+1
    if (index==9): break

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График истинности") # заголовок
plt.xlabel("t, пиксель") # ось абсцисс
plt.ylabel("X, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(t, Y,'r',label="Результат X - измерение")  # построение графика
plt.plot(df_FK['t'], df_FK['x'],'b',label="Результат X - ФК")  # построение графика
plt.legend(loc=0)
plt.savefig('График истинности')

# %%
t=[]
t_before=0
index=0

for i in df_Y['t']:
    t.append(t_before+i)
    t_before=t_before+i
    index=index+1
    if (index==9): break

Y=[]
index=0
for i in df_Y['y']:
    Y.append(i)
    index=index+1
    if (index==9): break


plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График истинности") # заголовок
plt.xlabel("t, пиксель") # ось абсцисс
plt.ylabel("X, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(t, Y,'r',label="Результат Y - измерение")  # построение графика
plt.plot(df_FK['t'], df_FK['y'],'b',label="Результат Y - ФК")  # построение графика
plt.legend(loc=0)
plt.savefig('График истинности')

# %%
t=[]
t_before=0
index=0

for i in df_Y['t']:
    t.append(t_before+i)
    t_before=t_before+i
    index=index+1
    if (index==9): break

Y=[]
index=0
for i in df_Y['alpha']:
    Y.append(i)
    index=index+1
    if (index==9): break


plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График истинности") # заголовок
plt.xlabel("t, пиксель") # ось абсцисс
plt.ylabel("X, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(t, Y,'r',label="Результат alpha - измерение")  # построение графика
plt.plot(df_FK['t'], df_FK['alpha'],'b',label="Результат alpha - ФК")  # построение графика
plt.legend(loc=0)
plt.savefig('График истинности')
