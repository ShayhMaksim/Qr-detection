# %%
Result_35_m10=[
    [105.6536841253853,105.9453959009],
    [105.32712641905904,105.9453959009],
    [107.42274986065965,105.9453959009],
    [107.44958073542001,105.9453959009],
    [107.44958073542001,105.9453959009]
]
Result_35_m12=[
    [108.69447450793187,108.9246444161],
]
Result_35_m15=[
    [111.89502506725222,113.1985905136],

]
Result_35_m30=[
    [123.79550464289149,130.601294645],
    [128.65727000541975,130.601294645],
    [124.04260783353634,130.601294645],
    [128.65727000541975,130.601294645],
    [128.65727000541975,130.601294645],
]

Result_35_m8=[
    [102.71681701327877,102.8750015596],
]

Result_35_m6=[
    [100.23278108920235,99.7275785514],
    [100.19450757942013,99.7275785514],
    [98.09203761686616,99.7275785514],
    [98.09203761686616,99.7275785514],
]

Result_35_m4=[
    [96.06620486288384, 96.51980175166],
    [96.08799036216503, 96.51980175166],
    [96.06620486288384, 96.51980175166],
]

# %%
Result_35_12=[
    [69.06932741823084,71.0753555839]
]
Result_35_10=[
    [73.23497633653777,74.0546040991],
    [75.45359908039003,74.0546040991],
    [73.42421693309672,74.0546040991],
    [73.48164433689048,74.0546040991],
]
Result_35_8=[
    [76.40272222477385,77.1249984404],
    [78.27594382791733,77.1249984404],
    [78.33082654669276,77.1249984404],
    [77.30385727546096,77.1249984404]
]
Result_35_4=[
    [82.10678458725587,83.48019824834],
    [84.15466951312017,83.48019824834],
    [82.11323166259558,83.48019824834]
]

# %%
X=[]
Y=[]

# %%
import numpy as np
Result_35_m10=np.mean([105.6536841253853,105.32712641905904,107.42274986065965,107.44958073542001])
Result_35_m12=np.mean([108.69447450793187])
Result_35_m15=np.mean([111.89502506725222])
Result_35_m30=np.mean([123.79550464289149,128.65727000541975,124.04260783353634,128.65727000541975,128.65727000541975])
Result_35_m8=np.mean([102.71681701327877])
Result_35_m6=np.mean([100.23278108920235,100.19450757942013,98.09203761686616,98.09203761686616])
Result_35_m4=np.mean([96.06620486288384,96.08799036216503,96.06620486288384])

Result_35_12=np.mean([69.06932741823084])
Result_35_10=np.mean([73.23497633653777,75.45359908039003,73.42421693309672,73.48164433689048])
Result_35_8=np.mean([76.40272222477385,78.27594382791733,78.33082654669276,77.30385727546096])
Result_35_4=np.mean([82.10678458725587,84.15466951312017,82.11323166259558])
Result_35_0=np.mean([90,90])
Result_35_30=np.mean([58.13734946938639,54.40953888482538,53.66312131108156,54.39131314298479])

# %%
X=[
    Result_35_m30,
    Result_35_m15,
    Result_35_m12,
    Result_35_m10,
    Result_35_m8,
    Result_35_m6,
    Result_35_m4,
    Result_35_0,
    Result_35_4,
    Result_35_8,
    Result_35_10,
    Result_35_12,
    Result_35_30
]
Y=[
    130.601294645,
    113.1985905136,
    108.9246444161,
    105.9453959009,
    102.8750015596,
    99.7275785514,
    96.51980175166,
    90,
    83.48019824834,
    77.1249984404,
    74.0546040991,
    71.0753555839,
    49.398705355

]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=30)
plt.rc('axes',titlesize=30)
plt.rc('legend', fontsize=30)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.title("График опыта") # заголовок
plt.xlabel("Истина") # ось абсцисс
plt.ylabel("Измерение") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(Y, X,'r',label="Измерения и истинные значения")  # построение графика
plt.savefig('График сравнения измерений с истинным значением')

# %%
Error=np.asarray(Y)-np.asarray(X)
t=[
    -30,
    -15,
    -12,
    -10,
    -8,
    -6,
    -4,
    0,
    4,
    8,
    10,
    12,
    30
]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=30)
plt.rc('axes',titlesize=30)
plt.rc('legend', fontsize=30)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.title("График ошибок") # заголовок
plt.xlabel("Градусы") # ось абсцисс
plt.ylabel("Ошибка измерений") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(Y,Error,'r',label="Измерения и истинные значения")  # построение графика
plt.savefig('График ошибок измерений')

# %%
90-40.601294645
# Out:
# 49.398705355

# %%
absError=np.abs(np.asarray(Y)-np.asarray(X))
k=len(Y)
x=["130.6","113.2","108.9","105.9","102.9","99.7"," 96.5","90","83.5","77.1","74.1","71.1","49.4"]
fig, ax = plt.subplots()
fig.set_figwidth(12)    #  ширина Figure
fig.set_figheight(6)    #  высота Figure
ax.bar(x, absError)
plt.rc('axes', labelsize=18)
plt.rc('axes',titlesize=18)
plt.rc('legend', fontsize=18)
plt.xlabel("Отклонение в градусах от оси Y") # ось абсцисс
plt.ylabel("Абсолютная ошибка") # ось ординат
plt.title("График ошибки расчета положения объекта относительно QR-кода") # заголовок
plt.savefig("Угол отклонения по оси Y")

# %%
len(absError)
# Out:
# 13

# %%
len(Y)
# Out:
# 13

# %%
len(X)
# Out:
# 13

# %%
Y
# Out:
# [130.601294645,
#  113.1985905136,
#  108.9246444161,
#  105.9453959009,
#  102.8750015596,
#  99.7275785514,
#  96.51980175166,
#  90,
#  83.48019824834,
#  77.1249984404,
#  74.0546040991,
#  71.0753555839,
#  49.398705355]
